# %%
import pandas as pd
import paramiko
import io

# %%
# SSH connection details
hostname = "quest.northwestern.edu"
username = "ekc5108"
password = "MB~b1@Qt413%"

# Establish SSH connection
client = paramiko.SSHClient()
client.set_missing_host_key_policy(paramiko.AutoAddPolicy())
client.connect(hostname, username=username, password=password)

sftp = client.open_sftp()
remote_file = sftp.open('/projects/b1044/Computational_Output/EKC/fmod_calc_runs_2/000000000524/035-EKC-A8C-75c-b-5-p_shapemapper_log.txt')
# read txt file
data = remote_file.read()
remote_file.close()
sftp.close()
client.close()

# %%
data
# Out:
# b"\n################################################################################\nStarted ShapeMapper v2.2.0 at 2023-06-21 10:18:27\nRunning from directory: /projects/b1044/Sequencing/SHAPE-Seq/EKC/20230617-DMS_fourU/035-EKC-A8C-75c-b-5-p\nargs:  --name 035-EKC-A8C-75c-b-5-p --target ./fourU_A8C.fa --out 035-EKC-A8C-75c-b-5-p --modified --R1 ./035-EKC-A8C-75c-b-5-p_S35_L001_R1_001.fastq.gz --R2 ./035-EKC-A8C-75c-b-5-p_S35_L001_R2_001.fastq.gz --dms --amplicon --overwrite --nproc 24\nUsing serial mode, which is currently required for DMS mode\nUsing default DMS max-bg of 0.02\n\tYou can manually override using the max-bg flag\nCreated pipeline at 2023-06-21 10:18:27\nRunning PrimerLocator at 2023-06-21 10:18:27 . . .\n. . . done at 2023-06-21 10:18:27\nRunning FastaFormatChecker at 2023-06-21 10:18:27 . . .\n. . . done at 2023-06-21 10:18:27\nRunning BowtieIndexBuilder at 2023-06-21 10:18:27 . . .\n. . . done at 2023-06-21 10:18:27\nRunning ProgressMonitor at 2023-06-21 10:18:27 . . .\n. . . done at 2023-06-21 10:18:28\nRunning QualityTrimmer1 at 2023-06-21 10:18:28 . . .\n. . . done at 2023-06-21 10:18:28\nRunning QualityTrimmer2 at 2023-06-21 10:18:28 . . .\n. . . done at 2023-06-21 10:18:29\nRunning Interleaver at 2023-06-21 10:18:29 . . .\n. . . done at 2023-06-21 10:18:30\nRunning Merger at 2023-06-21 10:18:30 . . .\n/```````````````````````````````````````````````````````````````````````````````\n|Merger (sample: Modified) output message: \n|----------------------------------------- \n| \n| java -Djava.library.path=/projects/b1044/Software/shapemapper2/internals/thirdparty/miniconda/envs/shapemapper_make/opt/bbmap-37.78/jni/ -ea -Xmx1000m -Xmx1000m -cp /projects/b1044/Software/shapemapper2/internals/thirdparty/miniconda/envs/shapemapper_make/opt/bbmap-37.78/current/ jgi.BBMerge vstrict=t in=stdin out=stdout outu=stdout interleaved=t usejni=t t=4\n| Executing jgi.BBMerge [vstrict=t, in=stdin, out=stdout, outu=stdout, interleaved=t, usejni=t, t=4]\n| Version 37.78 [vstrict=t, in=stdin, out=stdout, outu=stdout, interleaved=t, usejni=t, t=4]\n| \n| Revised arguments: [maxbad=4, margin=3, minqo=8, qualiters=2, ratiomode=t, flatmode=f, minentropy=52, minoverlap=12, minoverlap0=4, maxratio=0.05, ratiomargin=12, ratiooffset=0.5, ratiominoverlapreduction=4, efilter=2, pfilter=0.008, minsecondratio=0.16, minapproxoverlap=22, in=stdin, out=stdout, outu=stdout, interleaved=t, usejni=t, t=4]\n| \n| Set INTERLEAVED to true\n| Set threads to 4\n| Writing mergable reads merged.\n| Unspecified format for output stdout; defaulting to fastq.\n| Unspecified format for output stdout; defaulting to fastq.\n| Started output threads.\n| Unspecified format for input stdin; defaulting to fastq.\n| Total time: 0.768 seconds.\n| \n| Pairs:               \t233024\n| Joined:              \t36252   \t15.557%\n| Ambiguous:           \t196772   \t84.443%\n| No Solution:         \t0       \t0.000%\n| Too Short:           \t0       \t0.000%\n| \n| Avg Insert:          \t106.0\n| Standard Deviation:  \t0.5\n| Mode:                \t106\n| \n| Insert range:        \t50 - 112\n| 90th percentile:     \t106\n| 75th percentile:     \t106\n| 50th percentile:     \t106\n| 25th percentile:     \t106\n| 10th percentile:     \t106\n\\_______________________________________________________________________________\n. . . done at 2023-06-21 10:18:31\nRunning Tab6Interleaver at 2023-06-21 10:18:31 . . .\n. . . done at 2023-06-21 10:18:32\nRunning BowtieAligner at 2023-06-21 10:18:32 . . .\n/```````````````````````````````````````````````````````````````````````````````\n|BowtieAligner (sample: Modified) output message: \n|------------------------------------------------ \n| \n| 233024 reads; of these:\n|   196772 (84.44%) were paired; of these:\n|     180710 (91.84%) aligned concordantly 0 times\n|     16061 (8.16%) aligned concordantly exactly 1 time\n|     1 (0.00%) aligned concordantly >1 times\n|     ----\n|     180710 pairs aligned concordantly 0 times; of these ...
